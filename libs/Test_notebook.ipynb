# %%
import matplotlib.pyplot as plt
import numpy as np

import os

# %%
n_points = 2000
slope = 0.004
bias = 4

history = []
avg_history = []
for i in range(n_points):
    noice = np.random.normal(0, 3)
    target = i * slope + bias + noice
    
    history.append(target)
    avg_history.append(np.mean(history[-100:]))

# %%
plt.figure(figsize=(14,10))


plt.plot(history, alpha=0.7, color='royalblue', label='Return')
plt.plot(avg_history, alpha=1, color='red', label='Avg Return (last 100)')
#plt.xlim([0-50,len(history)+50])
plt.grid(True)
plt.title('Agent Performance', fontsize=20)
plt.xlabel('Episode', fontsize=15)
plt.ylabel('Return/Score', fontsize=15)
plt.legend(loc='upper left')


path = './Basic_Actor_Critic'
os.makedirs(path, exist_ok=True)

file = os.path.join(path, 'plot')
plt.savefig(file, format='jpg')

# %%
# Out:
# Signature: os.mkdir(path, mode=511, *, dir_fd=None)
# Docstring:
# Create a directory.
#
# If dir_fd is not None, it should be a file descriptor open to a directory,
#   and path should be relative; path will then be relative to that directory.
# dir_fd may not be implemented on your platform.
#   If it is unavailable, using it will raise a NotImplementedError.
#
# The mode argument is ignored on Windows.
# Type:      builtin_function_or_method

# %%
t = np.random.normal(0, 3, 10)
t
# Out:
# array([ 1.2454012 ,  0.20615679,  1.90897281, -4.48273181, -0.89295754,
#        -2.4174271 ,  0.86934672,  1.67768828, -2.62647354,  3.14288498])

# %%
t[-100:]
# Out:
# array([ 1.2454012 ,  0.20615679,  1.90897281, -4.48273181, -0.89295754,
#        -2.4174271 ,  0.86934672,  1.67768828, -2.62647354,  3.14288498])

# %%
[np.mean(temp[-100:]) temp for]
# Out:
# 1.24540120047335
